# %%
import pandas as pd

# Load your CSV file into a DataFrame
wildfire_data = pd.read_csv('/Applications/fire.csv')

# Display the first few rows of the DataFrame
wildfire_data.head()
# Out:
#    fire_year  fire_number  current_size  fire_location_latitude  \
# 0       2021            1          5.50               59.522139
# 1       2021            2          0.01               52.692262
# 2       2021            3          0.10               55.937050
# 3       2021            4          0.01               56.425933
# 4       2021            5          7.13               53.693450
#
#    fire_location_longitude         fire_origin general_cause_desc  \
# 0              -119.926971     Provincial Land          Lightning
# 1              -116.118960     Provincial Land    Forest Industry
# 2              -110.719950  Indian Reservation         Incendiary
# 3              -111.160750  Indian Reservation           Resident
# 4              -116.058633        Private Land           Resident
#
#   industry_identifier_desc responsible_group_desc       activity_class  ...  \
# 0                      NaN                    NaN                  NaN  ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(wildfire_data['current_size'], bins=50, kde=True, color='skyblue', log_scale=(True, True))
plt.title('Distribution of Wildfire Sizes (Log Scale)')
plt.xlabel('Wildfire Size (Log Scale)')
plt.ylabel('Frequency (Log Scale)')
plt.show()
